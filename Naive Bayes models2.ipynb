# %% [markdown]
# ## find the prime number in 1 to 100 and condition for do not include 1,3 and 7 another number show output

# %%
for i in range(1,101):
    for j in range(2,i):
        if i%j==0:
            break
    else:
        val=str(i)
        if '1' in val or '3' in val or '7' in val:
            pass
        else:
            print(val)
# Out:
# 2
# 5
# 29
# 59
# 89

# %% [markdown]
# ## Naive Bayes models

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer

# %%
data=pd.read_csv('/home/sathish/Downloads/archive(72)/Instagram.csv')
data
# Out:
#                                   reviewId  ... score
# 0     5e177f92-db2e-4e59-b5c8-f1cf49c062fc  ...     1
# 1     267e3314-3050-46ab-bb90-d59c2f6f0874  ...     5
# 2     db7d6c45-9c26-4e94-98ec-98b0c7d804cc  ...     5
# 3     e011ed6a-f8ad-4c22-9fab-996163a75491  ...     5
# 4     15e8f8ff-1aff-42ba-a0c4-4d2ac3cb86f9  ...     2
# ...                                    ...  ...   ...
# 9995  9f8f5f09-f976-4f41-aebe-200122be6d8f  ...     5
# 9996  57bfbd96-e086-465f-ad65-113b72846940  ...     5
# 9997  b046b5bb-e472-4711-9533-f640b6c95791  ...     5
# 9998  d1af5b81-1561-4939-a3d7-a24c98dbb2a4  ...     1
# 9999  0959d766-23b5-4cd1-ab6f-2e9419ced4a8  ...     5
#
# [10000 rows x 3 columns]

# %%
data.isnull().sum()
# Out:
# reviewId    0
# content     2
# score       0
# dtype: int64

# %%
# drop rows with missing values

data = data.dropna()


# create a CountVectorizer instance

#vec = CountVectorizer(stop_words='english')


# fit and transform the data

#data = vec.fit_transform(data['text']).toarray()

# %%
def preprocess_data(data):

    data=data.drop('reviewId',axis=1)

    data['content']=data['content'].str.strip().str.lower()
    return data
data=preprocess_data(data)
data.head()
# Out:
#                       content  score
# 0  password incorrect problem      1
# 1                madakuduvura      5
# 2     loooooooo g lnsta brand      5
# 3                        nice      5
# 4                       actor      2

# %%
data.isnull().sum()
# Out:
# content    0
# score      0
# dtype: int64

# %%
x=data['content']
y=data['score']
x,x_test,y,y_test=train_test_split(x,y,stratify=y,test_size=0.25,random_state=42)

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Assuming x is a list of strings
vec = CountVectorizer(stop_words='english')
x = vec.fit_transform(x).toarray()
x_test = vec.transform(x_test).toarray()

# %%
from sklearn.naive_bayes import MultinomialNB
model1=MultinomialNB()
model1.fit(x,y)
# Out:
# MultinomialNB()

# %%
print(model1.score(x_test,y_test))
print(model1.predict(vec.transform(['Love this app simply awessome!'])))
print(model1.predict(vec.transform(['This word is used to describe a review that is strongly critical or unfavorable.'])))
# Out:
# 0.7076
# [5]
# [5]
