# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
churn_data=pd.read_csv("/home/sathish/Downloads/churn_data.csv")
customer_data=pd.read_csv("/home/sathish/Downloads/customer_data.csv")
internet_data=pd.read_csv("/home/sathish/Downloads/internet_data.csv")

# %%
df_1=pd.merge(churn_data,customer_data,how='inner',on='customerID')
row_data=pd.merge(df_1,internet_data,how='inner',on='customerID')

# %%
row_data
# Out:
#       customerID  tenure PhoneService  ... TechSupport StreamingTV StreamingMovies
# 0     7590-VHVEG       1           No  ...          No          No              No
# 1     5575-GNVDE      34          Yes  ...          No          No              No
# 2     3668-QPYBK       2          Yes  ...          No          No              No
# 3     7795-CFOCW      45           No  ...         Yes          No              No
# 4     9237-HQITU       2          Yes  ...          No          No              No
# ...          ...     ...          ...  ...         ...         ...             ...
# 7038  6840-RESVB      24          Yes  ...         Yes         Yes             Yes
# 7039  2234-XADUH      72          Yes  ...          No         Yes             Yes
# 7040  4801-JZAZL      11           No  ...          No          No              No
# 7041  8361-LTMKD       4          Yes  ...          No          No              No
# ...

# %%
telecom=row_data.copy()

# %%
varlist=['PhoneService']

def binary_map(x):
    return x.map({"Yes":1,"No":0})
telecom[varlist]=telecom[varlist].apply(binary_map)

# %%
#telecom['PhoneService']=telecom['PhoneService'].map({"yes":1,"no":0})
#telecom['PaperlessBilling']=telecom['PaperlessBilling'].map({"yes":1,"no":0})
#telecom['Churn']=telecom['Churn'].map({"yes":1,"no":0})
#telecom['Partner']=telecom['Partner'].map({"yes":1,"no":0})
#telecom['Dependents']=telecom['Dependents'].map({"yes":1,"no":0})

# %%
telecom
# Out:
#       customerID  tenure  PhoneService  ... TechSupport StreamingTV StreamingMovies
# 0     7590-VHVEG       1             0  ...          No          No              No
# 1     5575-GNVDE      34             1  ...          No          No              No
# 2     3668-QPYBK       2             1  ...          No          No              No
# 3     7795-CFOCW      45             0  ...         Yes          No              No
# 4     9237-HQITU       2             1  ...          No          No              No
# ...          ...     ...           ...  ...         ...         ...             ...
# 7038  6840-RESVB      24             1  ...         Yes         Yes             Yes
# 7039  2234-XADUH      72             1  ...          No         Yes             Yes
# 7040  4801-JZAZL      11             0  ...          No          No              No
# 7041  8361-LTMKD       4             1  ...          No          No              No
# ...
